# %% [markdown]
# # [NTDS'18] milestone 4: graph signal processing
# [ntds'18]: https://github.com/mdeff/ntds_2018
#
# [Rodrigo Pena](https://people.epfl.ch/254838), [EPFL LTS2](http://lts2.epfl.ch)

# %% [markdown]
# ## Students
#
# * Team: `Team 07`
# * Students: `Mathieu Lamiot, Julien Heitmann, Louis Landelle, Mathias Goncalves`
# * Dataset: `US Senators`

# %% [markdown]
# ## Rules
#
# * Milestones have to be completed by teams. No collaboration between teams is allowed.
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * You cannot import any other library than we imported.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart & Run All" in Jupyter.

# %% [markdown]
# ## Objective
#
# The goal of this milestone is to do some Graph Signal Processing (GSP) on the data of your project.
#
# ### A note about plotting
#
# There are several questions in this milestone that ask you to plot a signal on your network.
# There are several ways from which you could approach it.
# In all cases, compute the position of the nodes a single time at the beginning, as this is likely to be a costly operation.
# Using a single layout for all the graph plots will also make it easier to compare the plots.
# Indeed, the only thing changing between plots is the signal displayed.
# You can represent the features/labels lying on the graph via node **colors**.
# To do so, make sure to have a consistent color map throughout and remember to display a colorbar and scale in all plots, so that we can tell what numbers the colors represent.
#
# * An option is to use the **Laplacian eigenmaps** that you have seen in the previous milestone to embed your graph on the plane. For example:
#   ```
#   from matplotlib import pyplot as plt
#   plt.scatter(eigenvectors[:, 1], eigenvectors[:, 2], c=signal, alpha=0.5)
#   plt.colorbar()
#   ```
# * Another option is to use the plotting capabilities of **[NetworkX](https://networkx.github.io)**.
#   See the documentation of its [drawing methods](https://networkx.github.io/documentation/stable/reference/drawing.html).
#   For example:
#   ```
#   import networkx as nx
#   graph = nx.from_scipy_sparse_matrix(adjacency)
#   coords = nx.spring_layout(graph)  # Force-directed layout.
#   coords = eigenvectors[:, 1:3]  # Laplacian eigenmaps.
#   nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=signal)
#   nx.draw_networkx_edges(graph, coords, alpha=0.3)
#   ```
# * Another option is to use the plotting capabilities of the **[PyGSP](https://github.com/epfl-lts2/pygsp)**, a Python package for Graph Signal Processing.
#   **Note that your are forbidden to use the PyGSP for anything else than plotting.**
#   See the documentation of its [plotting utilities](https://pygsp.readthedocs.io/en/stable/reference/plotting.html).
#   For example:
#   ```
#   import pygsp as pg
#   graph = pg.graphs.Graph(adjacency)
#   graph.set_coordinates('spring')  # Force-directed layout.
#   graph.set_coordinates(eigenvectors[:, 1:3])  # Laplacian eigenmaps.
#   graph.plot_signal(signal)
#   ```
# * Yet another option is to save your graph on disk, use **[Gephi](https://gephi.org)** externally, to visualize the graph, save the graph with the Gephi coordinates and finally load the nodes coordinates back into the notebook.
#
# We encourage you to try all the above methods before making your choice. Then be consistent and use only one throughout the milestone.
# NetworkX and PyGSP should already be installed in your environement. If that's not the case, install with `conda install networkx pygsp` (after activating the `ntds_2018` environment).

# %% [markdown]
# ## 0 - Load your network

# %%
# %matplotlib inline

# %% [markdown]
# If you get a `No module named 'pyunlocbox'` error when running the below cell, install the [pyunlocbox](https://github.com/epfl-lts2/pyunlocbox) with `conda install pyunlocbox` (after activating the `ntds_2018` environment).

# %%
import numpy as np
from scipy import sparse
import scipy.sparse.linalg
from matplotlib import pyplot as plt
from pyunlocbox import functions, solvers
import networkx as nx

# %% [markdown]
# For this milestone, all we will need is a set of features/labels for each of the nodes on the network, as well as the Laplacian, $L,$ and Gradient, $\nabla_G,$ matrices that you have computed for your network while working on milestone 3.
#
# Import those objects in the cell below (or recompute the Laplacian and Gradient from your stored adjacency matrix, if you wish).
#
# _Note_: If your features/labels are not floating-point numbers, please convert them. For example, if your data has labels "cat" and "dog" for nodes that represent cats or dogs, respectively, you may assign the number `1.0` for the label "cat" and the number `-1.0` for the label "dog".

# %%
def grad(adjacency):
    #Retrieve infos on edges and nodes
    n_edges = int(np.sum(np.sign(adjacency))/2)
    n_nodes =  adjacency.shape[0]
    #Initialize the S matrix
    S = np.zeros((n_nodes, n_edges))
    #List the couples of connected nodes
    indices = np.argwhere(np.triu(adjacency))
    #For each couple of connected nodes, add the edge in the S matrix
    for ind, x in enumerate(indices):
        S[x[0],ind] = np.sqrt(adjacency[x[0],x[1]])
        S[x[1],ind] = -np.sqrt(adjacency[x[0],x[1]])
    return S.T

# %%
#Load the data
adjacency = np.load("adjacencyV2.npy")
degree_vect = np.sum(adjacency,axis=1)
degree_matrix = np.diag(degree_vect)

#Construct Laplacian
laplacian = degree_matrix-adjacency
np.save("laplacian.npy", laplacian)

#Compute gradient
gradient = grad(adjacency)

#Load and convert the labels
parties = np.load("party.npy")
labels = (((parties == 'R')*1)-0.5)*2
n_nodes =  adjacency.shape[0]

# %% [markdown]
# ## 1 - Graph Fourier Transform
#
# In this section we will observe how your feature/label vector looks like in the "Graph Fourier" domain.

# %% [markdown]
# ### Question 1
#
# Compute the Fourier basis vectors and the Laplacian eigenvalues. Make sure to order those from smaller to larger, $\lambda_0 \leq \lambda_1 \leq \dots \leq \lambda_{N-1},$ and use the same ordering for the Fourier basis vectors.

# %%
e, U = scipy.linalg.eigh(laplacian)

# %% [markdown]
# Plot the first 3 and the last Fourier basis vectors as signals on your graph. Clearly indicate which plot belongs to which basis vector.

# %%
graph = nx.from_scipy_sparse_matrix(scipy.sparse.csr_matrix(adjacency))
coords = nx.spring_layout(graph)  # Force-directed layout.

plt.figure(figsize= (15,15))
plt.subplot(321)
plt.title("Eigenvector 0")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=U[:,0], vmin = 0, vmax= 1)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(323)
plt.title("Eigenvector 1")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=U[:,1])
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(325)
plt.title("Eigenvector 2")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=U[:,2])
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(322)
plt.title("Eigenvector 97")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=U[:,-3])
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(324)
plt.title("Eigenvector 98")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=U[:,-2])
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(326)
plt.title("Eigenvector 99")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=U[:,-1])
nx.draw_networkx_edges(graph, coords, alpha=0.3)
# Out:
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:

# %% [markdown]
# ### Question 2
#
# What can you observe in terms of local variations when comparing the basis vectors corresponding to the smallest eigenvalues to those corresponding to the largest eigenvalue? How would this justify the interpretation of the eigenvalues as "graph frequencies"?

# %% [markdown]
# **Your answer here.**
# Local variations for small eigenvalues are smaller: the signal over the graph doesn't change much. For high eigenvalues, we have stronger variations. This is even true for the 3rd smallest eigenvalue: even if it seems that there is a strong variation on one node, it is a not-well connected node. Hence, this is a smaller variation than the one we see on high eigenvalues that imply variations on strongly connected nodes.

# %% [markdown]
# ### Question 3
#
# Implement a function that returns the Graph Fourier Transform (GFT) of a given vector $x \in \mathbb{R}^{N},$ with respect to your graph, and a function that computes the corresponding inverse GFT (iGFT).

# %%
def GFT(x):
    y = U.T.dot(x)
    return y 

def iGFT(x):
    y = U.dot(x)
    return y

# %% [markdown]
# ### Question 4
#
# Plot your feature/label vector as a signal on your graph

# %%
plt.figure(figsize= (5,5))
plt.subplot(111)
plt.title("True labels over the graph")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=labels)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
# Out:
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:

# %% [markdown]
# Plot the absolute values of the GFT of your feature/label signal as a function of the graph eigenvalues. Make sure to add a marker indicating the position of each graph eigenvalue, and remember to properly name the axes.

# %%
labels_GFT = GFT(labels)
plt.plot(np.abs(labels_GFT))
plt.ylabel('Absolute value of labels_GFT')
plt.xlabel('Eigenvalue index')
plt.title("Label filter in the spectral domain")
# Out:
# Text(0.5,1,'Label filter in the spectral domain')

# %% [markdown]
# ### Question 5
#
# Discuss the behavior of the GFT that you plotted in the last question via comparing the plot of your label signal and those of the Fourier basis of Question 1. Would you consider your labels a "low-pass" or "high-pass" signal, or yet something else entirely?

# %% [markdown]
# **Your answer here.** The GFT of labels is mostly similar to the second eigenvector according to our plots. Hence, it is coherent that the most important value of labels_GFT appear on the 2nd eigenvector. Our labels are hence a band-pass on the 2nd frequency.

# %% [markdown]
# ## 2 - Filtering on graphs
#
# In this section we will check how filtered Dirac impulses diffuse on your graph.

# %% [markdown]
# ### Question 6
#
# Implement the following three filter kernels and the graph filtering operation.
#
# - The **heat kernel** is supposed to take in a vector of eigenvalues `e` and a parameter `t` and output a vector of evaluations of the heat kernel at those eigenvalues (see the course slides for help).
# - The **inverse filter** kernel is supposed to take in a vector of eigenvalues `e` and a parameter `t` and implement spectrally the  filter defined in the node domain by $f_{out}  = (I + t L)^{-1} f_{in},$ where $f_{in}, f_{out} \in \mathbb{R}^{N}$ are, repectively, the input and output signals to the filter.
# - The **rectangle kernel** takes in a vector of eigenvalues `e` and parameters `l_min` and `l_max` and returns `1.0` at coordinates satisfying $(e[l] \geq l_{min}) \wedge (e[l] \leq l_{max}),$ and `0.0` otherwise.
# - The **graph filtering** operation takes a graph signal $x \in \mathbb{R}^{N}$, a spectral graph `kernel` and a set of keyworded variables, and returns the corresponding filtered signal.
#     - _Hint:_ Remember that you have implemented the `GFT` and `iGFT` operations in Question 3.
#     - The `**kwargs` is a placeholder to collect supplementary pairs of keyword-values that are not known by the implementation before execution time.
#       The `kwargs` variable is a dictionary whose keyes and values are the parameter names and values.
#       This is useful to allow both `graph_filter(x, heat_kernel, tau=1.0)` and `graph_filter(x, rectangle_kernel, lambda_min=0.0, lambda_max=1.0)` to be valid calls from the same implementation.
#       One can then defer the keyword-value assignment to the `kernel` call: `foo = kernel(bar, **kwargs)`.

# %%
def heat_kernel(e, t):
    return np.exp(-t*e)

def inverse_kernel(e, t):
    return 1. / (1+(t*e))

def rectangle_kernel(e, l_min, l_max):
    return ((e > l_min) & (e < l_max))*1

def graph_filter(x, kernel, **kwargs):
    return iGFT(kernel(**kwargs)*GFT(x))

# %% [markdown]
# ### Question 7
#
# Plot all three filter kernels in the spectral domain. Remember to properly name the axes and title the plots. Choose filter parameters that best approximate the behavior of the GFT of your feature/label signal (as seen in Question 4).

# %%
t_heat = 0.3

plt.figure(figsize= (15,5))
plt.subplot(131)
plt.plot(np.abs(heat_kernel(e,t_heat)))
plt.ylabel('Absolute value of heat kernel spectrum')
plt.xlabel('Eigenvalue index')
plt.title("Heat kernel filter in the spectral domain")

t_inv = 0.5

plt.subplot(132)
plt.plot(np.abs(inverse_kernel(e,t_inv)))
plt.ylabel('Absolute value of inverse kernel spectrum')
plt.xlabel('Eigenvalue index')
plt.title("inverse kernel filter in the spectral domain")

#The following values are chosen to only keep the 2nd frequency
l_min_rect = 0.49
l_max_rect = 0.493

plt.subplot(133)
plt.plot(np.abs(rectangle_kernel(e,l_min_rect,l_max_rect)))
plt.ylabel('Absolute value of rectangle kernel spectrum')
plt.xlabel('Eigenvalue index')
plt.title("Rectangle kernel filter in the spectral domain")
# Out:
# Text(0.5, 1.0, 'Rectangle kernel filter in the spectral domain')

# %% [markdown]
# ### Question 8
#
# Consider two Dirac impulses arbitrarily placed on your graph. Plot their filtered versions by the three filter kernels implemented in Question 6.

# %%
# Generate two diracs
#dirac_loc = np.random.randint(0,high=100,size=2)
dirac_loc = [64,84] #To get the same results each time, we fix the locations of the diracs
f_in = np.zeros(100)
f_in[dirac_loc] = 1

#Filter the input signal
f_heat = graph_filter(f_in,heat_kernel,e=e,t=t_heat)
f_inv = graph_filter(f_in,inverse_kernel,e=e,t=t_inv)
f_rect = graph_filter(f_in,rectangle_kernel,e=e,l_min=l_min_rect, l_max=l_max_rect)


#Plot
plt.figure(figsize= (15,15))
plt.subplot(221)
plt.title("Input signal: 2 diracs")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=f_in)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(222)
plt.title("Output of the heat kernel filter")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=f_heat)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(223)
plt.title("Output of the inverse kernel filter")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=f_inv)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(224)
plt.title("Output of the rectangle kernel filter")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=f_rect)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
# Out:
# C:\Users\agadg\Anaconda3\envs\ntds_2018\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
#BONUS: interactive plot to visualize diffusion of heat kernel according to parameter t
from ipywidgets import widgets
from ipywidgets import interact, interactive, fixed, interact_manual
def interactive_heat(t_heat):
    f_heat = graph_filter(f_in,heat_kernel,e=e,t=t_heat)
    plt.figure(figsize= (5,5))
    plt.title("Filtered signal with heat kernel")
    nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=f_heat)
    nx.draw_networkx_edges(graph, coords, alpha=0.3)
interact(interactive_heat,t_heat=widgets.FloatSlider(min=0,max=0.15,step=0.01,value=0.05))
# Out:
# interactive(children=(FloatSlider(value=0.05, description='t_heat', max=0.15, step=0.01), Output()), _dom_clas…
# <function __main__.interactive_heat>

# %% [markdown]
# Comment on the "diffusion" of the Diracs induced by the filters. What does it say about the "communication" of information across your network? Relate that to the network connectivity measures that you analyzed during the previous milestones.

# %% [markdown]
# **Your answer here.**
# In this example, the two diracs are in the same "community". After filtering, the diracs propagates to the entire community, but not theh other one. The diffusion is very efficient for the heat kernel and the rectangle kernel; and less important with the inverse kernel.
#
# This is coherent with our previous observations: there are clearly two communities, with many intra-connections but few inter_connections. Hence, information propagates well inside a community but has difficulties going further.

# %% [markdown]
# ## 3 - De-noising
#
# In this section we will add some centered Gaussian noise to your feature/label signal and attempt to recover it.

# %% [markdown]
# ### Question 9
#
# In the cell below, set the noise variance $\sigma^2$ by making sure that the signal-to-noise ratio $SNR = \frac{\operatorname{Var}(\text{labels})}{\sigma^2}$ is about  $1.5$.
#
# _Note:_ Actually, you might want to play with the noise variance here and set it to different values and see how the denoising filters behave.

# %%
noise_std = (np.var(labels) / 1.5)**(0.5)
noisy_measurements = labels + noise_std * np.random.randn(n_nodes)

# %% [markdown]
# ### Question 10
#
# In the denoising setting, a common graph signal processing assumption is that the signal $z$ that we want to recover is "smooth", in the sense that $\|\nabla_G z\|_2 = \sqrt{z^{\top} L z}$ is small, while remaining "close" to the measurements that we start with. This leads to denoising by solving the following optimization problem:
#
# $$
# z_\star = \text{arg} \, \underset{z \in \mathbb{R}^{N}}{\min} \, \|z - y\|_2^2 + \gamma z^{\top} L z,
# $$
#
# where $y \in \mathbb{R}^{N}$ is the vector of noisy measurements.
#
# Derive the close form solution to this problem giving $z_\star$ as a function of $y$, $\gamma$ and $L$. Does this solution correspond to any graph filtering operation that you know?

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# Let $R(z) = \|z - y\|_2^2 + \gamma z^{\top} L z, z \in \mathbb{R}^{N}$ be the function we want to minimize. When computing the derivative with respect to $z(l)$, we get that:
#
# \begin{align}
# \frac{\partial R}{\partial z(l)}(z) &=  \frac{\partial}{\partial z(l)} \Big[ \sum_{i=1}^N (z(i) - y(i))^2 + \frac{\gamma}{2} \sum_{i,j} W(i,j) (z(i) - z(j))^2 \Big] \\
# &= 2(z(l) - y(l)) + 2\gamma \sum_{j=1}^{N} W(l,j) (z(l) - z(j))
# \end{align}
#
# This yields the following gradient, w.r.t. the components of $z$:
# $$
# \nabla R(z) = 2(z-y) + 2\gamma L z
# $$
#
# Solving $ \nabla R(z_\star) = 0 $ gives us:
#
# \begin{align}
# \nabla R(z_\star) = 0 &\Leftrightarrow \qquad (z_\star-y) + \gamma L z_\star = 0 \\
# &\Leftrightarrow \qquad (\hat{z}_\star -\hat{y}) + \gamma \widehat{L z_\star} = 0 \\
# &\Leftrightarrow \qquad  \hat{z}_\star (l) + \gamma \lambda_l \hat{z}_\star (l) = \hat{y} (l) \\
# &\Leftrightarrow \qquad \hat{z}_\star (l) = \frac{1}{1 + \gamma \lambda_l} \hat{y} (l)
# \end{align}
#
# Here $\hat{f}$ denotes the GFT of a signal $f$ on the graph. Notice that this graph filtering operation corresponds to a Low Pass filter. Moreover, using functional calculus, given $g$ a function defined for the eigenvalues of $L$, if $ \hat{z}_\star (l) = g(\lambda_l) \hat{y} (l) $, then the corresponding graph filter is represented by the function $g$ evaluated at the laplacian $L$: $z_\star = g(L) y$. In our case $g(L) = (1 + \gamma L)^{-1} $, which caracterizes an inverse filter kernel with parameter $ t = \gamma}$.

# %% [markdown]
# ### Question 11
#
# Now, denoise the noisy measurements by passing them through the filters that you implemented in Question 6. Choose the filter parameters based on the behavior of the GFT of your original label signal (this is the prior knowledge that you input to the problem).

# %%
t_heat = 0.3
t_inv = 0.5
l_min_rect = 0.49
l_max_rect = 0.493
z_heat_denoised = graph_filter(noisy_measurements, heat_kernel, e=e, t=t_heat)
z_inv_denoised = graph_filter(noisy_measurements, inverse_kernel, e=e, t=t_inv)
z_rect_denoised = graph_filter(noisy_measurements, rectangle_kernel, e=e, l_min=l_min_rect, l_max=l_max_rect)

# %% [markdown]
# Plot, on your graph, the original label signal, the noisy measurements, and the three denoised version obtained above. Report on each plot the value of the corresponding relative error
# $$
# \text{rel-err} = \frac{\|\text{labels} - z \|_2}{\|\text{labels}\|_2},
# $$
# where $z$ is the plotted signal.

# %%
"""
Given the ground truth vector 'labels' and its estimate 'z', computes the relative error.
Arguments:
    ground_truth: random vector 'labels' of length 100, that we are trying to identify
    estimate: our estimate of the actual vector 'labels' 
"""    
def relative_error(labels, z):
    assert labels.size == z.size
    numerator = np.linalg.norm(labels - z)
    denominator = np.linalg.norm(labels)
    return numerator / denominator

# %%
# Your code here.
heat_rel_err = relative_error(labels, z_heat_denoised)
inv_rel_err = relative_error(labels, z_inv_denoised)
rect_rel_err = relative_error(labels, z_rect_denoised)

plt.figure(figsize= (15,20))
plt.subplot(321)
plt.title("True labels over the graph")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=labels)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(322)
plt.title("Noisy measurements: SNR = 1.5")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=noisy_measurements)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(323)
plt.title(f"Heat kernel reconstructed signal, rel_err = {heat_rel_err:.3f}")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=z_heat_denoised)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(324)
plt.title(f"Inverse filter reconstructed signal, rel_err = {inv_rel_err:.3f}")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=z_inv_denoised)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
plt.subplot(325)
plt.title(f"Rectangle kernel reconstructed signal, rel_err = {rect_rel_err:.3f}")
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=z_rect_denoised)
nx.draw_networkx_edges(graph, coords, alpha=0.3)

print(f"Heat-kernel relative error: {heat_rel_err}")
print(f"Heat-kernel relative error: {inv_rel_err}")
print(f"Heat-kernel relative error: {rect_rel_err}")
# Out:
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:
# Heat-kernel relative error: 0.09482539776495132
# Heat-kernel relative error: 0.13394867272973734
# Heat-kernel relative error: 0.14853827100046416

# %% [markdown]
# Finally, overlay on the same plot the GFT of all five signals above.

# %%
# Your code here.
labels_GFT = GFT(labels)
noisy_measurements_GFT = GFT(noisy_measurements)
z_heat_GFT = GFT(z_heat_denoised)
z_inv_GFT = GFT(z_inv_denoised)
z_rect_GFT = GFT(z_rect_denoised)
plt.figure(figsize= (15,10))
plt.plot(labels_GFT, label="labels")
plt.plot(noisy_measurements_GFT, label="noisy_measurements")
plt.plot(z_heat_GFT, label="z_heat_denoised")
plt.plot(z_inv_GFT, label="z_inv_denoised")
plt.plot(z_rect_GFT, label="z_rect_denoised")
plt.ylabel('Graph Fourier Transform')
plt.xlabel('Eigenvalue index')
plt.title("GFT of signals")
plt.legend()

# %% [markdown]
# ### Question 12
#
# Comment on which denoised version seems to best match the original label signal. What is the underlying assumption behind the three filtering approaches? Do you think it holds for your label signal? Why?

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# It is not obvious which denoised version does best at matching the original label signal, they all approximate it pretty well (high peak at second eigenvalue, flat elsewhere). Nonetheless, the heat denoised signal has the smallest relative error. The underlying assumption behind the three filtering approaches is that the original label signal is smooth on the graph, which is clearly the case (we observed a true division between democrats and republicans).

# %% [markdown]
# ## 4 - Transductive learning
#
# It is often the case in large networks that we can only afford to query properties/labels on a small subset of nodes. Nonetheless, if the underlying labels signal is "regular" enough, we might still be able to recover a good approximation of it by solving an offline variational problem, with constraints on the values of the measured nodes.
#
# In this section, we will be interested in solving such transductive learning problems by minimizing a (semi-) p-norm of the graph gradient applied to the signal of interest:
#
# $$
# \text{arg} \, \underset{z|_S = y}{\min} \|\nabla_G z\|_p^p,
# $$
#
# where $S$ is the set of measured nodes.
#
# In English, we can say that we are looking for solutions with small "aggregated local variations", as measured by $\|\nabla_G z\|_p^p = \sum_{i=1}^{n} \sum_{j=1}^{n} \left( \sqrt{W_{ij}} |z[i] - z[j]| \right)^p,$ while satisfying the measurement constraints $z[i] = y[i]$ for $i \in S.$
#
# We will work with two cases, according to the choices $p=1$ or $p=2.$ For $p=1,$ the problem is known as "interpolation by graph total-variation minimization," whereas for $p=2$ it is sometimes called "interpolation by Tikhonov regularization".
#
# In order to solve these variational problems with the black-box solver provided to you, you will use the [pyunlocbox](https://pyunlocbox.readthedocs.io). This toolbox implements iterative solvers based on so-called ["proximal-splitting"](https://en.wikipedia.org/wiki/Proximal_gradient_method) methods.

# %% [markdown]
# ### Question 13
#
# Throughout this section, we will consider only a binarized version of your label signal. If your variable `labels` currently has values other than $\{-1, 1\},$ threshold them so that those are the only values taken in this vector. This can be done for example by choosing a number $t \in \mathbb{R}$ and then setting $\text{labels_bin}[i] = 1$ if $\text{labels}[i] \geq t$ and $\text{labels_bin}[i] = 0$ otherwise.

# %%
labels_bin = labels

# %% [markdown]
# Now, subsample this binarized label signal by $70\%$ by choosing, uniformly at random, $30\%$ of the nodes whose labels we will keep.
#
# You will do this by computing a "measurement mask" vector `w` with `1.0`'s at the measured coordinates, and $0.0$'s otherwise.

# %%
def sample_mask(ratio):
    m = int(ratio * n_nodes)
    nodes_indices = range(n_nodes)
    rand_indices = np.random.choice(nodes_indices, size=m, replace=False)

    w = np.zeros(n_nodes, dtype=np.int8)
    w[rand_indices] = 1
    return w

mn_ratio = 0.3
w = sample_mask(mn_ratio)
sub_signal = w*labels

# %% [markdown]
# Plot the subsampled signal on the graph. _Hint:_ you might want to set to `numpy.nan` the values of the un-measured nodes for a cleaner plot.

# %%
plt.figure(figsize=(8, 8))
plt.subplot(111)
sub_signal_toplot = sub_signal
sub_signal_toplot[sub_signal_toplot==0] = np.nan
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=sub_signal_toplot)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
# Out:
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:

# %% [markdown]
# ### Interlude
#
# For the solution of the variational problems you can use the following function as a "black-box".
#
# You will just need to provide a `gradient` matrix (which you should already have from Section 0), and an orthogonal projection operator `P` onto the span of the measured coordinates (made precise in the next question).

# %%
from scipy.sparse import issparse

def graph_pnorm_interpolation(gradient, P, x0=None, p=1., **kwargs):
    r"""
    Solve an interpolation problem via gradient p-norm minimization.

    A signal :math:`x` is estimated from its measurements :math:`y = A(x)` by solving
    :math:`\text{arg}\underset{z \in \mathbb{R}^n}{\min}
    \| \nabla_G z \|_p^p \text{ subject to } Az = y` 
    via a primal-dual, forward-backward-forward algorithm.

    Parameters
    ----------
    gradient : array_like
        A matrix representing the graph gradient operator
    P : callable
        Orthogonal projection operator mapping points in :math:`z \in \mathbb{R}^n` 
        onto the set satisfying :math:`A P(z) = A z`.
    x0 : array_like, optional
        Initial point of the iteration. Must be of dimension n.
        (Default is `numpy.random.randn(n)`)
    p : {1., 2.}
    kwargs :
        Additional solver parameters, such as maximum number of iterations
        (maxit), relative tolerance on the objective (rtol), and verbosity
        level (verbosity). See :func:`pyunlocbox.solvers.solve` for the full
        list of options.

    Returns
    -------
    x : array_like
        The solution to the optimization problem.

    """
    
    grad = lambda z: gradient.dot(z)
    div = lambda z: gradient.transpose().dot(z)

    # Indicator function of the set satisfying :math:`y = A(z)`
    f = functions.func()
    f._eval = lambda z: 0
    f._prox = lambda z, gamma: P(z)

    # :math:`\ell_1` norm of the dual variable :math:`d = \nabla_G z`
    g = functions.func()
    g._eval = lambda z: np.sum(np.abs(grad(z)))
    g._prox = lambda d, gamma: functions._soft_threshold(d, gamma)

    # :math:`\ell_2` norm of the gradient (for the smooth case)
    h = functions.norm_l2(A=grad, At=div)

    if issparse(gradient):
        stepsize = (0.9 / (1. + scipy.sparse.linalg.norm(gradient, ord='fro'))) ** p
    else:
        stepsize = (0.9 / (1. + np.linalg.norm(gradient, ord='fro'))) ** p

    solver = solvers.mlfbf(L=grad, Lt=div, step=stepsize)

    if p == 1.:
        problem = solvers.solve([f, g, functions.dummy()], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    if p == 2.:
        problem = solvers.solve([f, functions.dummy(), h], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    else:
        return x0

# %% [markdown]
# ### Question 14
#
# During the iterations of the algorithm used for solving the variational problem, we have to make sure that the labels at the measured nodes stay the same. We will do this by means of an operator `P` which, given a vector $a \in \mathbb{R}^{N},$ returns another vector $b \in \mathbb{R}^{N}$ satisfying $b[i] = \text{labels_bin}[i]$ for every node $i$ in the set $S$ of known labels, and $b[i] = a[i]$ otherwise. Write in the cell below the function for this orthogonal projection operator `P`.
#
# _Hint:_ remember you have already computed the mask `w`.

# %%
def P_for_w(w):
    def P(a):
        b = a.copy()
        S = np.nonzero(w)
        b[S] = labels_bin[S]
        return b
    return P

# %% [markdown]
# ### Question 15
#
# Solve the variational problems for $p = 1$ and $p = 2$. Record the solution for the $1-$norm minimization under `sol_1norm_min` and the one for $2-$norm minimization under `sol_2norm_min`.
#
# Compute also binarized versions of these solutions by thresholding the values with respect to $0$, that is, non-negative values become `1.0`, while negative values become `-1.0`. Store those binarized versions under `sol_1norm_bin` and `sol_2norm_bin`, respectively.

# %%
from scipy.sparse import issparse

sol_1norm_min = graph_pnorm_interpolation(gradient, P_for_w(w), p=1., x0=np.random.randn(n_nodes))
sol_2norm_min = graph_pnorm_interpolation(gradient, P_for_w(w), p=2., x0=np.random.randn(n_nodes))

threshold = 0

sol_1norm_bin = ((sol_1norm_min>threshold)*1)*2-1

sol_2norm_bin = ((sol_2norm_min>threshold)*1)*2-1

plt.figure(figsize=(4, 4))
plt.subplot(111)
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=sol_2norm_min)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
# Out:
# Solution found after 91 iterations:
#     objective function f(sol) = 4.023623e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.678457e+02
#     stopping criterion: MAXIT
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:

# %% [markdown]
# Plot, on your graph, the original `labels_bin` signal, as well as the solutions to the variational problems (both binarized and otherwise). Indicate on each plot the value of the relative error $\text{rel-err} = \frac{\|\text{labels_bin} - z\|_2}{\|\text{labels_bin}\|_2}$, where $z$ is the signal in the corresponding plot.

# %%
rel_err = lambda labels_bin, z: np.linalg.norm(labels_bin - z) / np.linalg.norm(labels_bin)
assert rel_err(np.array([2, 0]), np.array([1, 0])) == .5

plt.figure(figsize=(8, 8))
plt.subplot(221)
plt.gca().set_title("rel-err = " + str(rel_err(labels_bin, sol_1norm_min)))
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=sol_1norm_min)
nx.draw_networkx_edges(graph, coords, alpha=0.3)

plt.subplot(222)
plt.gca().set_title("rel-err = " + str(rel_err(labels_bin, sol_2norm_min)))
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=sol_2norm_min)
nx.draw_networkx_edges(graph, coords, alpha=0.3)

plt.subplot(223)
plt.gca().set_title("rel-err = " + str(rel_err(labels_bin, sol_1norm_bin)))
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=sol_1norm_bin)
nx.draw_networkx_edges(graph, coords, alpha=0.3)

plt.subplot(224)
plt.gca().set_title("rel-err = " + str(rel_err(labels_bin, sol_2norm_bin)))
nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=sol_2norm_bin)
nx.draw_networkx_edges(graph, coords, alpha=0.3)
# Out:
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /usr/lib/python3/dist-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:

# %% [markdown]
# ### Question 16
#
# Now that you have got a feeling for the sort of solutions that the transductive learning problems studied can give, we will see what is the effect of the number of measurements on the accuracy of both $p-$norm minimization problems.
#
# Towards this goal, you will write a `phase_transition()` function. This function will basically go over all the procedures that you have implemented in this section, but for varying numbers of measurements and thresholding values. It will also compute the relative error, $\text{rel-err},$ of the solutions and average them over a number of trials.
#
# The output of the `phase_transition()` function has to be a matrix with `len(mn_ratios)` columns and `len(thresholds)` rows. Each pixel $(i,j)$ in the output matrix has to contain the average, over `n_trials` trials, of the relative error $\text{rel-err}$ in the binarized (with threshold `thresholds[i]`) solution given by `graph_pnorm_interpolation()` from observing an `mn_ratios[j]` fraction of nodes. The randomness comes from a different choice of mask `w` at each trial, hence the averaging.
#
# The interest of this phase transition matrix is to assess what level of recovery error one could expect for a certain fraction of measurements and a certain threshold level.

# %%
def phase_transition(mn_ratios, thresholds, n_trials, labels_bin, p):
    pt_matrix = np.zeros((mn_ratios.shape[0], thresholds.shape[0]))

    # Create sample mask.
    ws = []
    for i in range(mn_ratios.shape[0]):
        ws.append(sample_mask(mn_ratios[i]))
            
        # Solve p-norm interpolation. 
        for j in range(thresholds.shape[0]):
            
            trials = np.zeros(n_trials)            
            for k in range(n_trials):
                sol_norm_min = graph_pnorm_interpolation(gradient, P_for_w(ws[i]), p=p, x0=np.random.randn(n_nodes))
                sol_norm_bin = ((sol_norm_min>thresholds[j])*1)*2-1
                trials[k] = rel_err(labels_bin, sol_norm_bin)
    
            # Aggregate.
            pt_matrix[i, j] = trials.mean()
    
    return pt_matrix

# %% [markdown]
# ### Question 17
#
# Pick 5 "m/n" ratios in $(0, 1)$ and 5 threshold levels in $(-1, 1)$ and run the `phase_transition()` function with `n_trials` = 20, for both $p = 1$ and $p = 2$.

# %%
mn_ratios = np.random.random(5)
print('mn_ratios', mn_ratios)

thresholds = np.random.random(5) * 2 - 1
print('thresholds', thresholds)

pt_matrix_1norm = phase_transition(mn_ratios, thresholds, 20, labels_bin, 1)
pt_matrix_2norm = phase_transition(mn_ratios, thresholds, 20, labels_bin, 2)
# Out:
# mn_ratios [0.62398147 0.14060673 0.44606208 0.89889361 0.11735159]
# thresholds [ 0.4866195   0.82696099 -0.93401461 -0.25952675 -0.41666288]
# Solution found after 56 iterations:
#     objective function f(sol) = 3.547207e+03
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 4.137553e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.154994e+03
#     stopping criterion: MAXIT
# Solution found after 156 iterations:
#     objective function f(sol) = 1.900570e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.496247e+03
#     stopping criterion: RTOL
# Solution found after 176 iterations:
#     objective function f(sol) = 1.316211e+03
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 1.693019e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.350950e+03
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.303298e+03
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.197034e+03
#     stopping criterion: MAXIT
# Solution found after 56 iterations:
#     objective function f(sol) = 3.376128e+03
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 2.914904e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 4.325222e+03
#     stopping criterion: RTOL
# Solution found after 123 iterations:
#     objective function f(sol) = 2.412633e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 2.244610e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 3.974841e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 5.097510e+03
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 2.859397e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 4.816194e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.253218e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.022577e+03
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 4.764067e+03
#     stopping criterion: RTOL
# Solution found after 122 iterations:
#     objective function f(sol) = 2.545782e+03
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 2.802997e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.208518e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.175890e+03
#     stopping criterion: MAXIT
# Solution found after 109 iterations:
#     objective function f(sol) = 1.177584e+03
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 2.856396e+03
#     stopping criterion: RTOL
# Solution found after 73 iterations:
#     objective function f(sol) = 1.037090e+03
#     stopping criterion: RTOL
# Solution found after 157 iterations:
#     objective function f(sol) = 2.107981e+03
#     stopping criterion: RTOL
# Solution found after 157 iterations:
#     objective function f(sol) = 1.950706e+03
#     stopping criterion: RTOL
# Solution found after 174 iterations:
#     objective function f(sol) = 9.445162e+02
#     stopping criterion: RTOL
# Solution found after 190 iterations:
#     objective function f(sol) = 1.717556e+03
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 1.266787e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 4.315202e+03
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 2.704603e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.396785e+03
#     stopping criterion: RTOL
# Solution found after 191 iterations:
#     objective function f(sol) = 1.982003e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 4.369403e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 5.006792e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.617405e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 1.464208e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 2.743579e+03
#     stopping criterion: RTOL
# Solution found after 76 iterations:
#     objective function f(sol) = 1.381622e+03
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 4.427526e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 4.302462e+03
#     stopping criterion: RTOL
# Solution found after 89 iterations:
#     objective function f(sol) = 2.553848e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.145760e+03
#     stopping criterion: MAXIT
# Solution found after 183 iterations:
#     objective function f(sol) = 1.528214e+03
#     stopping criterion: RTOL
# Solution found after 155 iterations:
#     objective function f(sol) = 1.934395e+03
#     stopping criterion: RTOL
# Solution found after 156 iterations:
#     objective function f(sol) = 2.091375e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 3.657103e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 2.831322e+03
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 2.833017e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.422928e+03
#     stopping criterion: RTOL
# Solution found after 123 iterations:
#     objective function f(sol) = 2.189487e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 4.358515e+03
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 1.190842e+03
#     stopping criterion: RTOL
# Solution found after 76 iterations:
#     objective function f(sol) = 1.463867e+03
#     stopping criterion: RTOL
# Solution found after 111 iterations:
#     objective function f(sol) = 1.417831e+03
#     stopping criterion: RTOL
# Solution found after 123 iterations:
#     objective function f(sol) = 2.282404e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 4.329445e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 4.445352e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 1.333622e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 3.407946e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 3.965726e+03
#     stopping criterion: RTOL
# Solution found after 155 iterations:
#     objective function f(sol) = 1.804987e+03
#     stopping criterion: RTOL
# Solution found after 123 iterations:
#     objective function f(sol) = 2.436971e+03
#     stopping criterion: RTOL
# Solution found after 192 iterations:
#     objective function f(sol) = 1.709285e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.172940e+03
#     stopping criterion: MAXIT
# Solution found after 38 iterations:
#     objective function f(sol) = 9.984886e+02
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.131748e+03
#     stopping criterion: MAXIT
# Solution found after 56 iterations:
#     objective function f(sol) = 3.208616e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 3.517694e+03
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 2.346335e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 3.983108e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 4.661866e+03
#     stopping criterion: RTOL
# Solution found after 158 iterations:
#     objective function f(sol) = 2.018021e+03
#     stopping criterion: RTOL
# Solution found after 157 iterations:
#     objective function f(sol) = 2.034020e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.394852e+03
#     stopping criterion: MAXIT
# Solution found after 90 iterations:
#     objective function f(sol) = 2.694613e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 2.662672e+03
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 4.249124e+03
#     stopping criterion: RTOL
# Solution found after 3 iterations:
#     objective function f(sol) = 1.116735e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 2.261207e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.481306e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.550543e+03
#     stopping criterion: RTOL
# Solution found after 190 iterations:
#     objective function f(sol) = 1.727740e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.560512e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.100759e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.016824e+03
#     stopping criterion: MAXIT
# Solution found after 56 iterations:
#     objective function f(sol) = 3.450847e+03
#     stopping criterion: RTOL
# Solution found after 171 iterations:
#     objective function f(sol) = 9.557573e+02
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 4.354522e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 3.283757e+03
#     stopping criterion: RTOL
# Solution found after 89 iterations:
#     objective function f(sol) = 2.610185e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.372288e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 4.884921e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.144810e+03
#     stopping criterion: MAXIT
# Solution found after 159 iterations:
#     objective function f(sol) = 1.811948e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.445412e+03
#     stopping criterion: RTOL
# Solution found after 75 iterations:
#     objective function f(sol) = 2.201002e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.441501e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.134960e+03
#     stopping criterion: MAXIT
# Solution found after 20 iterations:
#     objective function f(sol) = 8.340711e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 7.886915e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 3.761296e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.450497e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.587132e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.675032e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.127802e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 4.001584e+03
#     stopping criterion: RTOL
# Solution found after 173 iterations:
#     objective function f(sol) = 1.883260e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.070070e+03
#     stopping criterion: RTOL
# Solution found after 158 iterations:
#     objective function f(sol) = 3.140101e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 7.705701e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.689126e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.471345e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.581202e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.173699e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 3.699480e+03
#     stopping criterion: RTOL
# Solution found after 192 iterations:
#     objective function f(sol) = 2.734030e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.337724e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.116069e+03
#     stopping criterion: RTOL
# Solution found after 107 iterations:
#     objective function f(sol) = 2.412964e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 3.851065e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.731576e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.055422e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 7.756642e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.230299e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 5.484247e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 1.311048e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 3.740422e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.742150e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.797330e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 1.670980e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.161430e+03
#     stopping criterion: RTOL
# Solution found after 192 iterations:
#     objective function f(sol) = 2.868728e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 5.605685e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.669498e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.554426e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 3.773486e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.114679e+03
#     stopping criterion: MAXIT
# Solution found after 91 iterations:
#     objective function f(sol) = 4.752615e+03
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 4.843230e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.321624e+03
#     stopping criterion: RTOL
# Solution found after 192 iterations:
#     objective function f(sol) = 2.653650e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.150629e+03
#     stopping criterion: MAXIT
# Solution found after 57 iterations:
#     objective function f(sol) = 5.699565e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 4.702092e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.674263e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.626051e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 7.979730e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.423333e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 3.792212e+03
#     stopping criterion: RTOL
# Solution found after 158 iterations:
#     objective function f(sol) = 3.234034e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.225736e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.242298e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 3.882175e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 4.411701e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.718735e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.764894e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 7.936436e+03
#     stopping criterion: RTOL
# Solution found after 158 iterations:
#     objective function f(sol) = 3.278036e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.214376e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 7.573992e+03
#     stopping criterion: RTOL
# Solution found after 107 iterations:
#     objective function f(sol) = 2.288492e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.011826e+03
#     stopping criterion: RTOL
# Solution found after 191 iterations:
#     objective function f(sol) = 2.656451e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.348229e+03
#     stopping criterion: RTOL
# Solution found after 108 iterations:
#     objective function f(sol) = 2.382830e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 3.778857e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.354007e+03
#     stopping criterion: MAXIT
# Solution found after 20 iterations:
#     objective function f(sol) = 7.777393e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.753285e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.196646e+03
#     stopping criterion: RTOL
# Solution found after 158 iterations:
#     objective function f(sol) = 3.162705e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.301681e+03
#     stopping criterion: MAXIT
# Solution found after 109 iterations:
#     objective function f(sol) = 2.126997e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.718537e+03
#     stopping criterion: RTOL
# Solution found after 159 iterations:
#     objective function f(sol) = 3.234968e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 3.875447e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.287811e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.601586e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.616217e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 7.858720e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.510245e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 7.948642e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.204665e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.077642e+03
#     stopping criterion: RTOL
# Solution found after 159 iterations:
#     objective function f(sol) = 3.320409e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 4.877258e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.078832e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.809034e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.089449e+03
#     stopping criterion: RTOL
# Solution found after 175 iterations:
#     objective function f(sol) = 2.110002e+03
#     stopping criterion: RTOL
# Solution found after 74 iterations:
#     objective function f(sol) = 2.179118e+03
#     stopping criterion: RTOL
# Solution found after 173 iterations:
#     objective function f(sol) = 1.970335e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.156089e+03
#     stopping criterion: MAXIT
# Solution found after 91 iterations:
#     objective function f(sol) = 4.574708e+03
#     stopping criterion: RTOL
# Solution found after 123 iterations:
#     objective function f(sol) = 3.001544e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.222707e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 5.760739e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.318803e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 4.750024e+03
#     stopping criterion: RTOL
# Solution found after 140 iterations:
#     objective function f(sol) = 1.490407e+03
#     stopping criterion: RTOL
# Solution found after 109 iterations:
#     objective function f(sol) = 1.700165e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.667086e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.308107e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 4.332341e+03
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 4.226216e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.356226e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.499064e+03
#     stopping criterion: RTOL
# Solution found after 175 iterations:
#     objective function f(sol) = 1.578139e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.549788e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.523174e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.422899e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.682879e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 3.124032e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.405163e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.798778e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.650119e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.780715e+03
#     stopping criterion: MAXIT
# Solution found after 125 iterations:
#     objective function f(sol) = 3.183631e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.690698e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.077326e+03
#     stopping criterion: RTOL
# Solution found after 158 iterations:
#     objective function f(sol) = 2.773865e+03
#     stopping criterion: RTOL
# Solution found after 158 iterations:
#     objective function f(sol) = 2.771168e+03
#     stopping criterion: RTOL
# Solution found after 173 iterations:
#     objective function f(sol) = 1.377970e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.057210e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 5.805227e+03
#     stopping criterion: RTOL
# Solution found after 143 iterations:
#     objective function f(sol) = 1.645400e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 5.444325e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.510177e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.167489e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.829767e+03
#     stopping criterion: MAXIT
# Solution found after 56 iterations:
#     objective function f(sol) = 4.683046e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.848078e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.686454e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.854445e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 3.189965e+03
#     stopping criterion: RTOL
# Solution found after 179 iterations:
#     objective function f(sol) = 1.582456e+03
#     stopping criterion: RTOL
# Solution found after 191 iterations:
#     objective function f(sol) = 2.086449e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.229189e+03
#     stopping criterion: RTOL
# Solution found after 126 iterations:
#     objective function f(sol) = 2.822339e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 3.055962e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 5.964845e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.126204e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.675476e+03
#     stopping criterion: RTOL
# Solution found after 177 iterations:
#     objective function f(sol) = 1.499507e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.935120e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 5.987947e+03
#     stopping criterion: RTOL
# Solution found after 74 iterations:
#     objective function f(sol) = 1.695089e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.779124e+03
#     stopping criterion: MAXIT
# Solution found after 20 iterations:
#     objective function f(sol) = 6.221033e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 1.310985e+03
#     stopping criterion: RTOL
# Solution found after 140 iterations:
#     objective function f(sol) = 1.427622e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 5.733516e+03
#     stopping criterion: RTOL
# Solution found after 145 iterations:
#     objective function f(sol) = 1.619030e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 2.839510e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.328391e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.208872e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 3.134231e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.247931e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 1.830984e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 4.750192e+03
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 6.106500e+03
#     stopping criterion: RTOL
# Solution found after 191 iterations:
#     objective function f(sol) = 2.213859e+03
#     stopping criterion: RTOL
# Solution found after 191 iterations:
#     objective function f(sol) = 2.156086e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.293233e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.716417e+03
#     stopping criterion: MAXIT
# Solution found after 20 iterations:
#     objective function f(sol) = 5.956642e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.820560e+03
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 4.256773e+03
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 3.968358e+03
#     stopping criterion: RTOL
# Solution found after 108 iterations:
#     objective function f(sol) = 1.563806e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.519687e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.169862e+03
#     stopping criterion: RTOL
# Solution found after 158 iterations:
#     objective function f(sol) = 2.867804e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 5.997490e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.523140e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.384246e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.367711e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.491355e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.441309e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 5.496130e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.361530e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.903408e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.214699e+03
#     stopping criterion: RTOL
# Solution found after 159 iterations:
#     objective function f(sol) = 2.616295e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 6.056703e+03
#     stopping criterion: RTOL
# Solution found after 140 iterations:
#     objective function f(sol) = 1.689311e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 3.019184e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 4.664375e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.669217e+03
#     stopping criterion: MAXIT
# Solution found after 158 iterations:
#     objective function f(sol) = 2.620454e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.791943e+03
#     stopping criterion: RTOL
# Solution found after 142 iterations:
#     objective function f(sol) = 1.571589e+03
#     stopping criterion: RTOL
# Solution found after 108 iterations:
#     objective function f(sol) = 1.749889e+03
#     stopping criterion: RTOL
# Solution found after 138 iterations:
#     objective function f(sol) = 1.389625e+03
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 1.100608e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 8.993488e+02
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 7.200764e+02
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 1.198531e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 1.612443e+03
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 4.174270e+02
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 1.032101e+03
#     stopping criterion: RTOL
# Solution found after 159 iterations:
#     objective function f(sol) = 7.016249e+02
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 1.344833e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 1.599324e+03
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 7.019134e+02
#     stopping criterion: RTOL
# Solution found after 19 iterations:
#     objective function f(sol) = 1.346498e+03
#     stopping criterion: RTOL
# Solution found after 118 iterations:
#     objective function f(sol) = 7.771683e+02
#     stopping criterion: RTOL
# Solution found after 22 iterations:
#     objective function f(sol) = 1.219123e+03
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 1.666374e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 1.358182e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 1.504655e+03
#     stopping criterion: RTOL
# Solution found after 189 iterations:
#     objective function f(sol) = 6.230310e+02
#     stopping criterion: RTOL
# Solution found after 22 iterations:
#     objective function f(sol) = 1.422343e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 1.866896e+03
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 1.207793e+03
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 3.346191e+02
#     stopping criterion: RTOL
# Solution found after 129 iterations:
#     objective function f(sol) = 6.654383e+02
#     stopping criterion: RTOL
# Solution found after 74 iterations:
#     objective function f(sol) = 4.809911e+02
#     stopping criterion: RTOL
# Solution found after 182 iterations:
#     objective function f(sol) = 5.172452e+02
#     stopping criterion: RTOL
# Solution found after 153 iterations:
#     objective function f(sol) = 7.674715e+02
#     stopping criterion: RTOL
# Solution found after 134 iterations:
#     objective function f(sol) = 6.473078e+02
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 1.419584e+03
#     stopping criterion: RTOL
# Solution found after 160 iterations:
#     objective function f(sol) = 7.667433e+02
#     stopping criterion: RTOL
# Solution found after 93 iterations:
#     objective function f(sol) = 1.097736e+03
#     stopping criterion: RTOL
# Solution found after 126 iterations:
#     objective function f(sol) = 9.222453e+02
#     stopping criterion: RTOL
# Solution found after 19 iterations:
#     objective function f(sol) = 1.533595e+03
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.861076e+02
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 1.011947e+03
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 1.195889e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 8.482105e+02
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 9.351650e+02
#     stopping criterion: MAXIT
# Solution found after 19 iterations:
#     objective function f(sol) = 1.651200e+03
#     stopping criterion: RTOL
# Solution found after 19 iterations:
#     objective function f(sol) = 1.509415e+03
#     stopping criterion: RTOL
# Solution found after 154 iterations:
#     objective function f(sol) = 6.587146e+02
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 1.675045e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 7.868161e+02
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 1.522451e+03
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 1.549696e+03
#     stopping criterion: RTOL
# Solution found after 19 iterations:
#     objective function f(sol) = 1.284131e+03
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 1.050716e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 1.001189e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 1.428966e+03
#     stopping criterion: RTOL
# Solution found after 107 iterations:
#     objective function f(sol) = 5.163857e+02
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 1.349003e+03
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 1.193436e+03
#     stopping criterion: RTOL
# Solution found after 22 iterations:
#     objective function f(sol) = 1.260634e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 1.493750e+03
#     stopping criterion: RTOL
# Solution found after 61 iterations:
#     objective function f(sol) = 8.414716e+02
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 1.042702e+03
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 1.027001e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 1.192135e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 1.093563e+03
#     stopping criterion: RTOL
# Solution found after 147 iterations:
#     objective function f(sol) = 4.654701e+02
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 9.047612e+02
#     stopping criterion: RTOL
# Solution found after 115 iterations:
#     objective function f(sol) = 4.537535e+02
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 1.648997e+03
#     stopping criterion: RTOL
# Solution found after 22 iterations:
#     objective function f(sol) = 1.963485e+03
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 8.652386e+02
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 8.159318e+02
#     stopping criterion: RTOL
# Solution found after 24 iterations:
#     objective function f(sol) = 1.122255e+03
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 5.650372e+02
#     stopping criterion: RTOL
# Solution found after 96 iterations:
#     objective function f(sol) = 9.475079e+02
#     stopping criterion: RTOL
# Solution found after 71 iterations:
#     objective function f(sol) = 6.215885e+02
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 1.296844e+03
#     stopping criterion: RTOL
# Solution found after 22 iterations:
#     objective function f(sol) = 1.345389e+03
#     stopping criterion: RTOL
# Solution found after 144 iterations:
#     objective function f(sol) = 4.348946e+02
#     stopping criterion: RTOL
# Solution found after 127 iterations:
#     objective function f(sol) = 7.564062e+02
#     stopping criterion: RTOL
# Solution found after 58 iterations:
#     objective function f(sol) = 1.076347e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 8.953552e+02
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 1.506873e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 9.152889e+02
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 7.203947e+02
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 6.210536e+02
#     stopping criterion: RTOL
# Solution found after 19 iterations:
#     objective function f(sol) = 1.125439e+03
#     stopping criterion: RTOL
# Solution found after 160 iterations:
#     objective function f(sol) = 6.462512e+02
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 1.632159e+03
#     stopping criterion: RTOL
# Solution found after 22 iterations:
#     objective function f(sol) = 1.127747e+03
#     stopping criterion: RTOL
# Solution found after 21 iterations:
#     objective function f(sol) = 1.439270e+03
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 8.794697e+02
#     stopping criterion: RTOL
# Solution found after 24 iterations:
#     objective function f(sol) = 1.396073e+03
#     stopping criterion: RTOL
# Solution found after 89 iterations:
#     objective function f(sol) = 8.135940e+02
#     stopping criterion: RTOL
# Solution found after 22 iterations:
#     objective function f(sol) = 1.691531e+03
#     stopping criterion: RTOL
# Solution found after 75 iterations:
#     objective function f(sol) = 6.197631e+02
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 4.857138e+02
#     stopping criterion: MAXIT
# Solution found after 57 iterations:
#     objective function f(sol) = 8.127353e+02
#     stopping criterion: RTOL
# Solution found after 19 iterations:
#     objective function f(sol) = 1.383853e+03
#     stopping criterion: RTOL
# Solution found after 89 iterations:
#     objective function f(sol) = 8.689122e+02
#     stopping criterion: RTOL
# Solution found after 54 iterations:
#     objective function f(sol) = 1.175792e+03
#     stopping criterion: RTOL
# Solution found after 165 iterations:
#     objective function f(sol) = 6.876532e+02
#     stopping criterion: RTOL
# Solution found after 3 iterations:
#     objective function f(sol) = 5.059882e+02
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 1.093295e+03
#     stopping criterion: RTOL
# Solution found after 154 iterations:
#     objective function f(sol) = 4.908969e+02
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 1.224710e+03
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 7.758017e+02
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.564588e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 3.804321e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.669040e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.791281e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.206240e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 4.843491e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.341739e+03
#     stopping criterion: RTOL
# Solution found after 74 iterations:
#     objective function f(sol) = 1.937657e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.781758e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.337028e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.696199e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.703549e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.751342e+03
#     stopping criterion: RTOL
# Solution found after 159 iterations:
#     objective function f(sol) = 3.347794e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.925676e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.882202e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 4.865665e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.584344e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.144070e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.248873e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.923572e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 1.648997e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.765190e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 4.826604e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.132515e+03
#     stopping criterion: MAXIT
# Solution found after 180 iterations:
#     objective function f(sol) = 2.164259e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
#     objective function f(sol) = 5.820157e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.003917e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.387049e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 3.988666e+03
#     stopping criterion: RTOL
# Solution found after 178 iterations:
#     objective function f(sol) = 1.974231e+03
#     stopping criterion: RTOL
# Solution found after 20 iterations:
#     objective function f(sol) = 8.792829e+03
#     stopping criterion: RTOL
# Solution found after 108 iterations:
#     objective function f(sol) = 2.405024e+03
#     stopping criterion: RTOL
# Solution found after 57 iterations:
# ...
# Solution found after 200 iterations:
#     objective function f(sol) = 5.422613e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.276892e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.549452e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.267029e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.264861e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.582892e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.382138e+01
#     stopping criterion: MAXIT
# Solution found after 178 iterations:
#     objective function f(sol) = 5.251371e+01
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 5.541175e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.881065e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.873433e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.379828e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.478757e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.541838e+01
#     stopping criterion: MAXIT
# Solution found after 195 iterations:
#     objective function f(sol) = 5.252660e+01
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 5.486796e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.354407e+01
#     stopping criterion: MAXIT
# Solution found after 190 iterations:
#     objective function f(sol) = 5.261492e+01
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 5.880784e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.579637e+01
#     stopping criterion: MAXIT
# Solution found after 173 iterations:
#     objective function f(sol) = 5.277455e+01
#     stopping criterion: RTOL
# Solution found after 195 iterations:
#     objective function f(sol) = 5.281777e+01
#     stopping criterion: RTOL
# Solution found after 196 iterations:
#     objective function f(sol) = 5.268219e+01
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 5.300627e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.404560e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.346702e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.343349e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.357599e+01
#     stopping criterion: MAXIT
# Solution found after 193 iterations:
#     objective function f(sol) = 5.278619e+01
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 5.293130e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.404175e+01
#     stopping criterion: MAXIT
# Solution found after 196 iterations:
#     objective function f(sol) = 5.251975e+01
#     stopping criterion: RTOL
# Solution found after 194 iterations:
#     objective function f(sol) = 5.276109e+01
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 5.547970e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.330453e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.449234e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.499794e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 5.380505e+01
#     stopping criterion: MAXIT
# Solution found after 171 iterations:
#     objective function f(sol) = 5.242747e+01
#     stopping criterion: RTOL
# Solution found after 195 iterations:
#     objective function f(sol) = 5.260283e+01
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 5.382308e+01
#     stopping criterion: MAXIT
# Solution found after 199 iterations:
#     objective function f(sol) = 5.279346e+01
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 5.349700e+01
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.609555e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.642735e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.274306e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.419714e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.673907e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.480611e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.692345e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.309008e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.301321e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.457652e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.977175e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.452711e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.887536e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.882719e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.679101e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.164607e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.512910e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.548944e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.113929e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.163050e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.103407e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.125862e+02
#     stopping criterion: MAXIT
# Solution found after 1 iterations:
#     objective function f(sol) = 3.875897e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.290054e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.998156e+02
#     stopping criterion: MAXIT
# Solution found after 1 iterations:
#     objective function f(sol) = 3.911394e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.856465e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.595845e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.808261e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.196567e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.662022e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.343145e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.135318e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.581759e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.678436e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.536987e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.508008e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.084807e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 3.683015e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.196856e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.830358e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.642908e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.517107e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.987061e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.895236e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.695425e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.547872e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.050602e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.363695e+02
#     stopping criterion: MAXIT
# Solution found after 1 iterations:
#     objective function f(sol) = 5.236253e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.288689e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.269556e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.111287e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.842572e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.515320e+02
#     stopping criterion: MAXIT
# Solution found after 1 iterations:
#     objective function f(sol) = 4.643673e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.259541e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.265802e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.121578e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 3.246001e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.178693e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.845504e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.290769e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.446374e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.571505e+02
#     stopping criterion: MAXIT
# Solution found after 1 iterations:
#     objective function f(sol) = 4.293483e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.890833e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.919946e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.378728e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.100677e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.814413e+02
#     stopping criterion: MAXIT
# Solution found after 1 iterations:
#     objective function f(sol) = 5.710757e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 2.590798e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 3.252883e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.738112e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.830643e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 3.073110e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.012568e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.356785e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.027294e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.035745e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.098509e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.624220e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.963561e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.192672e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.741258e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.303216e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.190769e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.011207e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.930300e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.284446e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.656288e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.654638e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.072671e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 3.435442e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.072774e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.258711e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.695428e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 2.188266e+02
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 3.463559e+02
#     stopping criterion: MAXIT

# %% [markdown]
# Plot both phase transition matrices as images with a colorbar. Make sure to properly name the axes and title the images.

# %%
from matplotlib import cm

#print(pt_matrix_1norm)
fig = plt.figure(figsize=(8, 8))

plt.subplot(121)
cax = plt.gca().imshow(pt_matrix_1norm, interpolation='nearest', cmap=cm.coolwarm)
plt.gca().set_title("rel-err = " + str(rel_err(labels_bin, sol_1norm_min)))

plt.subplot(122)
cax = plt.gca().imshow(pt_matrix_2norm, interpolation='nearest', cmap=cm.coolwarm)
plt.gca().set_title("rel-err = " + str(rel_err(labels_bin, sol_2norm_min)))
# Out:
# Text(0.5,1,'rel-err = 0.32827048520004815')

# %% [markdown]
# ### Question 18
#
# Do the phase transition plots above provide any justification for choosing one $p-$norm interpolation over the other? Why?

# %% [markdown]
# **Your answer here.**
